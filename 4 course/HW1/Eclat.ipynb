# %% [markdown]
# # АЛГОРИТМ ECLAT

# %% [markdown]
# Алгоритм ECLAT расшифровывается как кластеризация классов эквивалентности и обход решетки снизу вверх . Это один из популярных методов объединения правил майнинга . Это более эффективная и масштабируемая версия алгоритма Apriori. Хотя алгоритм Apriori работает в горизонтальном смысле, имитируя поиск графика по ширине, алгоритм ECLAT работает по вертикали, как поиск графика по глубине. Этот вертикальный подход алгоритма ECLAT делает его более быстрым алгоритмом, чем алгоритм Apriori.

# %% [markdown]
# ### Как работает алгоритм?

# %% [markdown]
# Основная идея состоит в том, чтобы использовать пересечения наборов идентификаторов транзакций (tidsets) для вычисления значения поддержки кандидата и избегать генерации подмножеств, которые не существуют в дереве префиксов. При первом вызове функции все отдельные элементы используются вместе с их наборами приливов. Затем функция вызывается рекурсивно, и в каждом рекурсивном вызове каждая пара элемент-тидсет проверяется и объединяется с другими парами элемент-тидсет. Этот процесс продолжается до тех пор, пока не будут объединены пары-кандидаты-тидсет.
#
# Давайте теперь разберемся с изложенным выше, работая с примером:

# %%
# подгрузим модули
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
# загрузим данные
dataset = pd.read_csv('./csvs/Online_Retail.csv', sep='\t', comment='#', header = None, delimiter = ';')
# Out:
# C:\Users\irina\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dataset.head(20)
# Out:
#             0          1                                    2         3  \
# 0   InvoiceNo  StockCode                          Description  Quantity
# 1      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2      536365      71053                  WHITE METAL LANTERN         6
# 3      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 4      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 5      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 6      536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 7      536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 8      536366      22633               HAND WARMER UNION JACK         6
# 9      536366      22632            HAND WARMER RED POLKA DOT         6
# 10     536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 11     536367      22745           POPPY'S PLAYHOUSE BEDROOM          6
# 12     536367      22748            POPPY'S PLAYHOUSE KITCHEN         6
# 13     536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 14     536367      22310              IVORY KNITTED MUG COSY          6
# 15     536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 16     536367      22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 17     536367      22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 18     536367      21754             HOME BUILDING BLOCK WORD         3
# 19     536367      21755             LOVE BUILDING BLOCK WORD         3
#
#                 4          5           6               7
# 0     InvoiceDate  UnitPrice  CustomerID         Country
# 1   01 12 10 8:26       2,55       17850  United Kingdom
# 2   01 12 10 8:26       3,39       17850  United Kingdom
# 3   01 12 10 8:26       2,75       17850  United Kingdom
# 4   01 12 10 8:26       3,39       17850  United Kingdom
# 5   01 12 10 8:26       3,39       17850  United Kingdom
# 6   01 12 10 8:26       7,65       17850  United Kingdom
# 7   01 12 10 8:26       4,25       17850  United Kingdom
# 8   01 12 10 8:28       1,85       17850  United Kingdom
# 9   01 12 10 8:28       1,85       17850  United Kingdom
# 10  01 12 10 8:34       1,69       13047  United Kingdom
# 11  01 12 10 8:34        2,1       13047  United Kingdom
# 12  01 12 10 8:34        2,1       13047  United Kingdom
# 13  01 12 10 8:34       3,75       13047  United Kingdom
# 14  01 12 10 8:34       1,65       13047  United Kingdom
# 15  01 12 10 8:34       4,25       13047  United Kingdom
# 16  01 12 10 8:34       4,95       13047  United Kingdom
# 17  01 12 10 8:34       9,95       13047  United Kingdom
# 18  01 12 10 8:34       5,95       13047  United Kingdom
# 19  01 12 10 8:34       5,95       13047  United Kingdom

# %%
dataset.fillna(method = 'ffill',axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#            0          1                                    2         3  \
# 0  InvoiceNo  StockCode                          Description  Quantity
# 1     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2     536365      71053                  WHITE METAL LANTERN         6
# 3     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 4     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#                4          5           6               7
# 0    InvoiceDate  UnitPrice  CustomerID         Country
# 1  01 12 10 8:26       2,55       17850  United Kingdom
# 2  01 12 10 8:26       3,39       17850  United Kingdom
# 3  01 12 10 8:26       2,75       17850  United Kingdom
# 4  01 12 10 8:26       3,39       17850  United Kingdom

# %%
transactions = []
for i in range(0, 7000): 
    transactions.append([str(dataset.values[i,j]) for j in [0, len(dataset.columns) - 1]])

# %%
transactions
# Out:
# [['InvoiceNo', 'Country'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536365', 'United Kingdom'],
#  ['536366', 'United Kingdom'],
#  ['536366', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536367', 'United Kingdom'],
#  ['536368', 'United Kingdom'],
#  ['536368', 'United Kingdom'],
#  ['536368', 'United Kingdom'],
#  ['536368', 'United Kingdom'],
#  ['536369', 'United Kingdom'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536370', 'France'],
#  ['536371', 'United Kingdom'],
#  ['536372', 'United Kingdom'],
#  ['536372', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536373', 'United Kingdom'],
#  ['536374', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536375', 'United Kingdom'],
#  ['536376', 'United Kingdom'],
#  ['536376', 'United Kingdom'],
#  ['536377', 'United Kingdom'],
#  ['536377', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536378', 'United Kingdom'],
#  ['536380', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['536381', 'United Kingdom'],
#  ['C536379', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['536382', 'United Kingdom'],
#  ['C536383', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536384', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536385', 'United Kingdom'],
#  ['536386', 'United Kingdom'],
#  ['536386', 'United Kingdom'],
#  ['536386', 'United Kingdom'],
#  ['536387', 'United Kingdom'],
#  ['536387', 'United Kingdom'],
#  ['536387', 'United Kingdom'],
#  ['536387', 'United Kingdom'],
#  ['536387', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536388', 'United Kingdom'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536389', 'Australia'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['536390', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['C536391', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536392', 'United Kingdom'],
#  ['536393', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536394', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536395', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536396', 'United Kingdom'],
#  ['536397', 'United Kingdom'],
#  ['536397', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536398', 'United Kingdom'],
#  ['536399', 'United Kingdom'],
#  ['536399', 'United Kingdom'],
#  ['536400', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536401', 'United Kingdom'],
#  ['536402', 'United Kingdom'],
#  ['536402', 'United Kingdom'],
#  ['536402', 'United Kingdom'],
#  ['536403', 'Netherlands'],
#  ['536403', 'Netherlands'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536404', 'United Kingdom'],
#  ['536405', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536406', 'United Kingdom'],
#  ['536407', 'United Kingdom'],
#  ['536407', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536408', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536409', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536412', 'United Kingdom'],
#  ['536414', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536415', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536416', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536420', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536423', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536425', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536437', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536446', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536460', 'United Kingdom'],
#  ['536463', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536464', 'United Kingdom'],
#  ['536466', 'United Kingdom'],
#  ['536466', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536477', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536488', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536500', 'United Kingdom'],
#  ['536502', 'United Kingdom'],
#  ['536502', 'United Kingdom'],
#  ['536502', 'United Kingdom'],
#  ['536502', 'United Kingdom'],
#  ['536502', 'United Kingdom'],
#  ['536508', 'United Kingdom'],
#  ['536508', 'United Kingdom'],
#  ['C536506', 'United Kingdom'],
#  ['536514', 'United Kingdom'],
#  ['536514', 'United Kingdom'],
#  ['536514', 'United Kingdom'],
#  ['536514', 'United Kingdom'],
#  ['536514', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ['536520', 'United Kingdom'],
#  ...]

# %%
import numpy as np
"""
Класс инициируется 3мя параметрами:
- min_supp - минимальный support  который мы рассматриваем для ItemSet. Рассчитывается как % от количества транзакций
- max_items - максимальное количество елементов в нашем ItemSet
- min_items - минимальное количество элементов ItemSet
"""
class Eclat:
    #инициализация объекта класса
    def __init__(self, min_support = 0.01, max_items = 5, min_items = 2):
        self.min_support = min_support
        self.max_items = max_items
        self.min_items = min_items
        self.item_lst = list()
        self.item_len = 0
        self.item_dict = dict()
        self.final_dict = dict()
        self.data_size = 0
    
    #создание словаря из ненулевых объектов из всех транзакций (вертикальный датасет)
    def read_data(self, dataset):
        for index, row in dataset.iterrows():
            row_wo_na = row.dropna().unique()
            for item in row_wo_na:
                item = str(item).strip()
                if item in self.item_dict:
                    self.item_dict[item][0] += 1
                else:
                    self.item_dict.setdefault(item, []).append(1)
                self.item_dict[item].append(index)
        #задаем переменные экземпляра (instance variables)
        self.data_size = dataset.shape[0]
        self.item_lst = list(self.item_dict.keys())
        self.item_len = len(self.item_lst)
        self.min_support = self.min_support * self.data_size
        #print ("min_supp", self.min_support)
        
    #рекурсивный метод для поиска всех ItemSet по алгоритму Eclat
    #структура данных: {Item: [Supp number, tid1, tid2, tid3, ...]}
    def recur_eclat(self, item_name, tids_array, minsupp, num_items, k_start):
        if tids_array[0] >= minsupp and num_items <= self.max_items:
            for k in range(k_start+1, self.item_len):
                if self.item_dict[self.item_lst[k]][0] >= minsupp:
                    new_item = item_name + " | " + self.item_lst[k]
                    new_tids = np.intersect1d(tids_array[1:], self.item_dict[self.item_lst[k]][1:])
                    new_tids_size = new_tids.size
                    new_tids = np.insert(new_tids, 0, new_tids_size)
                    if new_tids_size >= minsupp:
                        if num_items >= self.min_items: self.final_dict.update({new_item: new_tids})
                        self.recur_eclat(new_item, new_tids, minsupp, num_items+1, k)
    
    #последовательный вызов функций определенных выше
    def fit(self, dataset):
        i = 0
        self.read_data(dataset)
        for w in self.item_lst:
            self.recur_eclat(w, self.item_dict[w], self.min_support, 2, i)
            i+=1
        return self
        
    #вывод в форме словаря {ItemSet: support(ItemSet)}
    def transform(self):
        return {k: "{0:.4f}%".format((v[0]+0.0)/self.data_size*100) for k, v in self.final_dict.items()}

# %%
#создадим экземпляр класса с нужными нам параметрами
model = Eclat(min_support = 0.01, max_items = 3, min_items = 3)

# %%
#обучим
model.fit(dataset)

# %%
#и визуализируем результаты
model.transform()

# %% [markdown]
# Преимущества перед алгоритмом Apriori:
#
# * Требования к памяти: поскольку алгоритм ECLAT использует метод поиска в глубину, он использует меньше памяти, чем алгоритм Apriori.
# * Скорость: алгоритм ECLAT обычно быстрее, чем алгоритм Apriori.
# * Количество вычислений: алгоритм ECLAT не предусматривает повторного сканирования данных для вычисления отдельных значений поддержки.
