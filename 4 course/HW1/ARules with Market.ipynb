# %%
from IPython.display import display, Math, Latex
from IPython.core.display import HTML

# %%
# подгрузим модули
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# загрузим данные
dataset = pd.read_csv('./csvs/market_basket.csv', header = None)

# %%
# посомтрим на датасет
dataset.head(20)
# Out:
#                    0             1              2                 3   \
# 0              shrimp       almonds        avocado    vegetables mix
# 1             burgers     meatballs           eggs               NaN
# 2             chutney           NaN            NaN               NaN
# 3              turkey       avocado            NaN               NaN
# 4       mineral water          milk     energy bar  whole wheat rice
# 5      low fat yogurt           NaN            NaN               NaN
# 6   whole wheat pasta  french fries            NaN               NaN
# 7                soup   light cream        shallot               NaN
# 8   frozen vegetables     spaghetti      green tea               NaN
# 9        french fries           NaN            NaN               NaN
# 10               eggs      pet food            NaN               NaN
# 11            cookies           NaN            NaN               NaN
# 12             turkey       burgers  mineral water              eggs
# 13          spaghetti     champagne        cookies               NaN
# 14      mineral water        salmon            NaN               NaN
# 15      mineral water           NaN            NaN               NaN
# 16             shrimp     chocolate        chicken             honey
# 17             turkey          eggs            NaN               NaN
# 18             turkey    fresh tuna       tomatoes         spaghetti
# 19          meatballs          milk          honey      french fries
#
#                4                 5               6               7   \
# 0    green grapes  whole weat flour            yams  cottage cheese
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4       green tea               NaN             NaN             NaN
# 5             NaN               NaN             NaN             NaN
# 6             NaN               NaN             NaN             NaN
# 7             NaN               NaN             NaN             NaN
# 8             NaN               NaN             NaN             NaN
# 9             NaN               NaN             NaN             NaN
# 10            NaN               NaN             NaN             NaN
# 11            NaN               NaN             NaN             NaN
# 12    cooking oil               NaN             NaN             NaN
# 13            NaN               NaN             NaN             NaN
# 14            NaN               NaN             NaN             NaN
# 15            NaN               NaN             NaN             NaN
# 16            oil       cooking oil  low fat yogurt             NaN
# 17            NaN               NaN             NaN             NaN
# 18  mineral water         black tea          salmon            eggs
# 19    protein bar               NaN             NaN             NaN
#
#               8                     9               10         11     12  \
# 0   energy drink          tomato juice  low fat yogurt  green tea  honey
# 1            NaN                   NaN             NaN        NaN    NaN
# 2            NaN                   NaN             NaN        NaN    NaN
# 3            NaN                   NaN             NaN        NaN    NaN
# 4            NaN                   NaN             NaN        NaN    NaN
# 5            NaN                   NaN             NaN        NaN    NaN
# 6            NaN                   NaN             NaN        NaN    NaN
# 7            NaN                   NaN             NaN        NaN    NaN
# 8            NaN                   NaN             NaN        NaN    NaN
# 9            NaN                   NaN             NaN        NaN    NaN
# 10           NaN                   NaN             NaN        NaN    NaN
# 11           NaN                   NaN             NaN        NaN    NaN
# 12           NaN                   NaN             NaN        NaN    NaN
# 13           NaN                   NaN             NaN        NaN    NaN
# 14           NaN                   NaN             NaN        NaN    NaN
# 15           NaN                   NaN             NaN        NaN    NaN
# 16           NaN                   NaN             NaN        NaN    NaN
# 17           NaN                   NaN             NaN        NaN    NaN
# 18       chicken  extra dark chocolate             NaN        NaN    NaN
# 19           NaN                   NaN             NaN        NaN    NaN
#
#        13             14      15                 16               17       18  \
# 0   salad  mineral water  salmon  antioxydant juice  frozen smoothie  spinach
# 1     NaN            NaN     NaN                NaN              NaN      NaN
# 2     NaN            NaN     NaN                NaN              NaN      NaN
# 3     NaN            NaN     NaN                NaN              NaN      NaN
# 4     NaN            NaN     NaN                NaN              NaN      NaN
# 5     NaN            NaN     NaN                NaN              NaN      NaN
# 6     NaN            NaN     NaN                NaN              NaN      NaN
# 7     NaN            NaN     NaN                NaN              NaN      NaN
# 8     NaN            NaN     NaN                NaN              NaN      NaN
# 9     NaN            NaN     NaN                NaN              NaN      NaN
# 10    NaN            NaN     NaN                NaN              NaN      NaN
# 11    NaN            NaN     NaN                NaN              NaN      NaN
# 12    NaN            NaN     NaN                NaN              NaN      NaN
# 13    NaN            NaN     NaN                NaN              NaN      NaN
# 14    NaN            NaN     NaN                NaN              NaN      NaN
# 15    NaN            NaN     NaN                NaN              NaN      NaN
# 16    NaN            NaN     NaN                NaN              NaN      NaN
# 17    NaN            NaN     NaN                NaN              NaN      NaN
# 18    NaN            NaN     NaN                NaN              NaN      NaN
# 19    NaN            NaN     NaN                NaN              NaN      NaN
#
#            19
# 0   olive oil
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %%
dataset.fillna(method = 'ffill',axis = 1, inplace = True)

# %% [markdown]
# Видим, что датасет у нас представляет разреженную матрицу, где в строках у нас набор items в каждой транзакции.

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs              eggs          eggs
# 2        chutney    chutney     chutney           chutney       chutney
# 3         turkey    avocado     avocado           avocado       avocado
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5          6               7             8             9   \
# 0  whole weat flour       yams  cottage cheese  energy drink  tomato juice
# 1              eggs       eggs            eggs          eggs          eggs
# 2           chutney    chutney         chutney       chutney       chutney
# 3           avocado    avocado         avocado       avocado       avocado
# 4         green tea  green tea       green tea     green tea     green tea
#
#                10         11         12         13             14         15  \
# 0  low fat yogurt  green tea      honey      salad  mineral water     salmon
# 1            eggs       eggs       eggs       eggs           eggs       eggs
# 2         chutney    chutney    chutney    chutney        chutney    chutney
# 3         avocado    avocado    avocado    avocado        avocado    avocado
# 4       green tea  green tea  green tea  green tea      green tea  green tea
#
#                   16               17         18         19
# 0  antioxydant juice  frozen smoothie    spinach  olive oil
# 1               eggs             eggs       eggs       eggs
# 2            chutney          chutney    chutney    chutney
# 3            avocado          avocado    avocado    avocado
# 4          green tea        green tea  green tea  green tea

# %%
transactions = []
for i in range(0, 100): 
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
import apyori
from apyori import apriori

# %%
# %%time
# и обучимся правилам. Обратите внимание, что пороговые значения мы вибираем сами в зависимости от того, /
# насколкьо "сильные" правила мы хотим получить
# min_support -- минимальный support для правил (dtype = float).
# min_confidence -- минимальное значение confidence для правил (dtype = float)
# min_lift -- минимальный lift (dtype = float)
# max_length -- максимальная длина itemset (вспоминаем про k-itemset)  (dtype = integer)

result = list(apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 4, min_length = 2, max_length = 2))
# Out:
# Wall time: 42.9 ms

# %% [markdown]
# Визуализируем выход

# %%
import shutil, os

# %%
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

# %%
import json #преобразовывать будем в json, используя встроенные в модуль методы

# %%
output = []
for RelationRecord in result:
    o = StringIO()
    apyori.dump_as_json(RelationRecord, o)
    output.append(json.loads(o.getvalue()))
data_df = pd.DataFrame(output)

# %%
# и взгялнем на итоги
pd.set_option('display.max_colwidth', None)

from IPython.display import display, HTML

display(HTML(data_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>ordered_statistics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[almonds, antioxydant juice]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['antioxydant juice'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['antioxydant juice'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[almonds, avocado]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['avocado'], 'confidence': 0.5, 'lift': 6.25}]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[almonds, burgers]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['burgers'], 'confidence': 0.5, 'lift': 5.0}]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[almonds, cookies]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['cookies'], 'confidence': 0.5, 'lift': 5.0}]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[almonds, cottage cheese]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['cottage cheese'], 'confidence': 0.5, 'lift': 25.0}, {'items_base': ['cottage cheese'], 'items_add': ['almonds'], 'confidence': 0.5, 'lift': 25.0}]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[almonds, energy drink]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['energy drink'], 'confidence': 0.5, 'lift': 12.5}, {'items_base': ['energy drink'], 'items_add': ['almonds'], 'confidence': 0.25, 'lift': 12.5}]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[almonds, frozen smoothie]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['frozen smoothie'], 'confidence': 0.5, 'lift': 12.5}, {'items_base': ['frozen smoothie'], 'items_add': ['almonds'], 'confidence': 0.25, 'lift': 12.5}]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[almonds, green grapes]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['green grapes'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['green grapes'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[almonds, green tea]</td>
#       <td>0.02</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['green tea'], 'confidence': 1.0, 'lift': 6.666666666666667}]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[almonds, honey]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['honey'], 'confidence': 0.5, 'lift': 10.0}]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[almonds, low fat yogurt]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['low fat yogurt'], 'confidence': 0.5, 'lift': 6.25}]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[almonds, olive oil]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['olive oil'], 'confidence': 0.5, 'lift': 16.666666666666668}, {'items_base': ['olive oil'], 'items_add': ['almonds'], 'confidence': 0.33333333333333337, 'lift': 16.666666666666668}]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[almonds, salad]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['salad'], 'confidence': 0.5, 'lift': 25.0}, {'items_base': ['salad'], 'items_add': ['almonds'], 'confidence': 0.5, 'lift': 25.0}]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[almonds, salmon]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['salmon'], 'confidence': 0.5, 'lift': 10.0}]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[almonds, shrimp]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['shrimp'], 'confidence': 0.5, 'lift': 8.333333333333334}]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[almonds, spinach]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['spinach'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['spinach'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[almonds, tomato juice]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['tomato juice'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['tomato juice'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[almonds, vegetables mix]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['vegetables mix'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['vegetables mix'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[almonds, whole weat flour]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['whole weat flour'], 'confidence': 0.5, 'lift': 50.0}, {'items_base': ['whole weat flour'], 'items_add': ['almonds'], 'confidence': 1.0, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[almonds, yams]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['yams'], 'confidence': 0.5, 'lift': 25.0}, {'items_base': ['yams'], 'items_add': ['almonds'], 'confidence': 0.5, 'lift': 25.0}]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[antioxydant juice, avocado]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['avocado'], 'confidence': 1.0, 'lift': 12.5}]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[antioxydant juice, cottage cheese]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['cottage cheese'], 'confidence': 1.0, 'lift': 50.0}, {'items_base': ['cottage cheese'], 'items_add': ['antioxydant juice'], 'confidence': 0.5, 'lift': 50.0}]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[antioxydant juice, energy drink]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['energy drink'], 'confidence': 1.0, 'lift': 25.0}, {'items_base': ['energy drink'], 'items_add': ['antioxydant juice'], 'confidence': 0.25, 'lift': 25.0}]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[antioxydant juice, frozen smoothie]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['frozen smoothie'], 'confidence': 1.0, 'lift': 25.0}, {'items_base': ['frozen smoothie'], 'items_add': ['antioxydant juice'], 'confidence': 0.25, 'lift': 25.0}]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[antioxydant juice, green grapes]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['green grapes'], 'confidence': 1.0, 'lift': 100.0}, {'items_base': ['green grapes'], 'items_add': ['antioxydant juice'], 'confidence': 1.0, 'lift': 100.0}]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[antioxydant juice, green tea]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['green tea'], 'confidence': 1.0, 'lift': 6.666666666666667}]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[antioxydant juice, honey]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['honey'], 'confidence': 1.0, 'lift': 20.0}]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[antioxydant juice, low fat yogurt]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['low fat yogurt'], 'confidence': 1.0, 'lift': 12.5}]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[antioxydant juice, mineral water]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['mineral water'], 'confidence': 1.0, 'lift': 4.0}]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[antioxydant juice, olive oil]</td>
#       <td>0.01</td>
#       <td>[{'items_base': ['antioxydant juice'], 'items_add': ['olive

# %% [markdown]
# Итого мы видим:
#
# 1. Пары items
# 2. items_base - первый элемент пары
# 3. items_add - второй (добавленный алгоритмом) элемент пары
# 4. confidence - значение confidence для пары
# 5. lift - значение lift для пары
# 6. support - начение support для пары. При желании, по нему можно отсортировать
#
#
# Результаты логичные: эскалоп и макароны, эскалоп и сливочно-грибной соус, курица и нежирная сметана, мягкий сыр и мед и т.д. - все это вполне логичные и, главное, вкусные сочетания:)

# %% [markdown]
# ### ECLAT Algorithm

# %%
import numpy as np
"""
Класс инициируется 3мя параметрами:
- min_supp - минимальный support  который мы рассматриваем для ItemSet. Рассчитывается как % от количества транзакций
- max_items - максимальное количество елементов в нашем ItemSet
- min_items - минимальное количество элементов ItemSet
"""
class Eclat:
    #инициализация объекта класса
    def __init__(self, min_support = 0.01, max_items = 5, min_items = 2):
        self.min_support = min_support
        self.max_items = max_items
        self.min_items = min_items
        self.item_lst = list()
        self.item_len = 0
        self.item_dict = dict()
        self.final_dict = dict()
        self.data_size = 0
    
    #создание словаря из ненулевых объектов из всех транзакций (вертикальный датасет)
    def read_data(self, dataset):
        for index, row in dataset.iterrows():
            row_wo_na = row.dropna().unique()
            for item in row_wo_na:
                item = item.strip()
                if item in self.item_dict:
                    self.item_dict[item][0] += 1
                else:
                    self.item_dict.setdefault(item, []).append(1)
                self.item_dict[item].append(index)
        #задаем переменные экземпляра (instance variables)
        self.data_size = dataset.shape[0]
        self.item_lst = list(self.item_dict.keys())
        self.item_len = len(self.item_lst)
        self.min_support = self.min_support * self.data_size
        #print ("min_supp", self.min_support)
        
    #рекурсивный метод для поиска всех ItemSet по алгоритму Eclat
    #структура данных: {Item: [Supp number, tid1, tid2, tid3, ...]}
    def recur_eclat(self, item_name, tids_array, minsupp, num_items, k_start):
        if tids_array[0] >= minsupp and num_items <= self.max_items:
            for k in range(k_start+1, self.item_len):
                if self.item_dict[self.item_lst[k]][0] >= minsupp:
                    new_item = item_name + " | " + self.item_lst[k]
                    new_tids = np.intersect1d(tids_array[1:], self.item_dict[self.item_lst[k]][1:])
                    new_tids_size = new_tids.size
                    new_tids = np.insert(new_tids, 0, new_tids_size)
                    if new_tids_size >= minsupp:
                        if num_items >= self.min_items: self.final_dict.update({new_item: new_tids})
                        self.recur_eclat(new_item, new_tids, minsupp, num_items+1, k)
    
    #последовательный вызов функций определенных выше
    def fit(self, dataset):
        i = 0
        self.read_data(dataset)
        for w in self.item_lst:
            self.recur_eclat(w, self.item_dict[w], self.min_support, 2, i)
            i+=1
        return self
        
    #вывод в форме словаря {ItemSet: support(ItemSet)}
    def transform(self):
        return {k: "{0:.4f}%".format((v[0]+0.0)/self.data_size*100) for k, v in self.final_dict.items()}

# %%
#создадим экземпляр класса с нужными нам параметрами
model = Eclat(min_support = 0.009, max_items = 4, min_items = 3)

# %%
#обучим
model.fit(dataset)

# %%
#и визуализируем результаты
model.transform()
# Out:
# {'mineral water | olive oil | spaghetti': '1.0265%',
#  'mineral water | eggs | milk': '1.3065%',
#  'mineral water | eggs | frozen vegetables': '0.9065%',
#  'mineral water | eggs | spaghetti': '1.4265%',
#  'mineral water | eggs | chocolate': '1.3465%',
#  'mineral water | eggs | ground beef': '1.0132%',
#  'mineral water | milk | frozen vegetables': '1.1065%',
#  'mineral water | milk | spaghetti': '1.5731%',
#  'mineral water | milk | chocolate': '1.3998%',
#  'mineral water | milk | ground beef': '1.1065%',
#  'mineral water | french fries | spaghetti': '1.0132%',
#  'mineral water | frozen vegetables | spaghetti': '1.1998%',
#  'mineral water | frozen vegetables | chocolate': '0.9732%',
#  'mineral water | frozen vegetables | ground beef': '0.9199%',
#  'mineral water | spaghetti | chocolate': '1.5865%',
#  'mineral water | spaghetti | tomatoes': '0.9332%',
#  'mineral water | spaghetti | pancakes': '1.1465%',
#  'mineral water | spaghetti | ground beef': '1.7064%',
#  'mineral water | chocolate | pancakes': '0.9332%',
#  'mineral water | chocolate | ground beef': '1.0932%',
#  'burgers | eggs | french fries': '0.9065%',
#  'eggs | milk | chocolate': '0.9199%',
#  'eggs | spaghetti | chocolate': '1.0532%',
#  'milk | spaghetti | chocolate': '1.0932%',
#  'milk | spaghetti | ground beef': '0.9732%',
#  'spaghetti | chocolate | ground beef': '0.9199%'}

# %% [markdown]
# ### FP-Growth Algorithm

# %%
import pyfpgrowth

# %%
# 1 способ
#Сгенериуем паттерны
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     almonds  antioxydant juice  asparagus  avocado  black tea  body spray  \
# 0      True               True      False     True      False       False
# 1     False              False      False    False      False       False
# 2     False              False      False    False      False       False
# 3     False              False      False     True      False       False
# 4     False              False      False    False      False       False
# ..      ...                ...        ...      ...        ...         ...
# 95    False              False      False    False      False        True
# 96    False              False      False    False      False       False
# 97    False              False      False    False      False       False
# 98    False              False      False    False      False       False
# 99    False              False      False    False      False       False
#
#     brownies  bug spray  burgers  butter  ...  tomatoes  toothpaste  turkey  \
# 0      False      False    False   False  ...     False       False   False
# 1      False      False     True   False  ...     False       False   False
# 2      False      False    False   False  ...     False       False   False
# 3      False      False    False   False  ...     False       False    True
# 4      False      False    False   False  ...     False       False   False
# ..       ...        ...      ...     ...  ...       ...         ...     ...
# 95     False      False    False   False  ...     False       False   False
# 96     False      False    False   False  ...     False       False    True
# 97     False      False    False   False  ...     False       False   False
# 98     False      False    False   False  ...     False       False   False
# 99     False      False    False   False  ...     False       False   False
#
#     vegetables mix  white wine  whole weat flour  whole wheat pasta  \
# 0             True       False              True              False
# 1            False       False             False              False
# 2            False       False             False              False
# 3            False       False             False              False
# 4            False       False             False              False
# ..             ...         ...               ...                ...
# 95           False       False             False              False
# 96           False       False             False              False
# 97           False       False             False              False
# 98           False       False             False              False
# 99           False       False             False               True
#
#     whole wheat rice   yams  yogurt cake
# 0              False   True        False
# 1              False  False        False
# 2              False  False        False
# 3              False  False        False
# 4               True  False        False
# ..               ...    ...          ...
# 95             False  False        False
# 96             False  False        False
# 97             False  False        False
# 98             False  False        False
# 99             False  False        False
#
# [100 rows x 88 columns]

# %%
# use fp-growth algorithm
from mlxtend.frequent_patterns import fpgrowth

f_patterns = fpgrowth(df, min_support=0.01, use_colnames=True)
f_patterns
# Out:
#          support  \
# 0           0.25
# 1           0.15
# 2           0.08
# 3           0.08
# 4           0.06
# ...          ...
# 1058227     0.01
# 1058228     0.01
# 1058229     0.01
# 1058230     0.01
# 1058231     0.01
#
#                                                                                     itemsets
# 0                                                                            (mineral water)
# 1                                                                                (green tea)
# 2                                                                                  (avocado)
# 3                                                                           (low fat yogurt)
# 4                                                                                   (shrimp)
# ...                                                                                      ...
# 1058227                        (pepper, turkey, frozen vegetables, tea, ham, oil, magazines)
# 1058228          (turkey, extra dark chocolate, frozen vegetables, tea, ham, oil, magazines)
# 1058229       (turkey, extra dark chocolate, frozen vegetables, tea, ham, pepper, magazines)
# 1058230             (pepper, turkey, extra dark chocolate, frozen vegetables, tea, ham, oil)
# 1058231  (pepper, turkey, extra dark chocolate, frozen vegetables, tea, ham, oil, magazines)
#
# [1058232 rows x 2 columns]

# %%
# 2 способ
#Сгенериуем паттерны
patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)
#Выучим правила
rules = pyfpgrowth.generate_association_rules(patterns, 30);
#Покажем
rules
# Out:
# {('mineral water', 'salmon', 'spaghetti'): (('black tea', 'escalope'), 33.0),
#  ('burgers', 'eggs', 'mineral water'): (('cooking oil', 'herb & pepper'),
#   35.0),
#  ('eggs', 'pasta'): (('shampoo',), 182.0),
#  ('burgers',
#   'pasta'): (('eggs', 'mineral water', 'olive oil', 'salt', 'spaghetti'),
#   42.0),
#  ('milk', 'mineral water', 'spaghetti'): (('escalope', 'ground beef'), 33.0),
#  ('burgers', 'spaghetti'): (('eggs', 'salt'), 42.0),
#  ('energy bar',
#   'mineral water',
#   'spaghetti'): (('burgers', 'olive oil', 'salt'), 42.0),
#  ('eggs', 'spaghetti'): (('extra dark chocolate', 'salmon'), 82.5),
#  ('eggs', 'mineral water', 'spaghetti'): (('burgers', 'olive oil', 'salt'),
#   42.0),
#  ('fresh bread', 'milk'): (('spaghetti',), 30.333333333333332),
#  ('avocado', 'mineral water'): (('whole wheat rice',), 30.333333333333332),
#  ('french fries', 'milk'): (('protein bar',), 60.0)}

# %% [markdown]
# В заключении эмпирически сравним **эффективность** метрикой *runtime* в зависимости от плотности датасета и длин транзакций датасета

# %% [markdown]
# Под *плотностью* датасета подразумеваестя отношение транзакций, содержащих в себе частые items к общему количеству транзакций.

# %% [markdown]
# <img src="./plot.PNG">

# %% [markdown]
# Из графика очевидно, что эффективность (чем меньше runtime, тем эффективнее) Apriori-алгоритма падает при увеличении плотности датасета.

# %% [markdown]
# Под *длинной транзакции* понимается количество в items в itemset

# %% [markdown]
# <img src="./plot2.PNG">
